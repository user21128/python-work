# %% [markdown]
# # Experiment 1
#
# Getting started with python 🐍

# %% [markdown]
# Q1: Write Python programs to print strings in the given manner:

# %%
print("hello")
print("world")
print("hello world")
print("hello everyone!!!")
print("hello everyone!!!")
# Out:
# hello
# world
# hello world
# hello everyone!!!
# hello everyone!!!

# %% [markdown]
# Q2: Declare a string variable called x and assign it the value “Hello”.
# Print out the value of x

# %%
x = "hello"
print(x)
# Out:
# hello

# %% [markdown]
# Q3: Take different data types and print values using print function.

# %%
x=1321
y="hello"
z=10.29
u=True
print(x)
print(y)
print(z)
print(u)
# Out:
# 1321
# hello
# 10.29
# True

# %% [markdown]
# Q4:  Take two variables, a and b. Assign your first name and last name. Print your
# Name after adding your First name and Last name together.

# %%
x="sumit"
y="joshi"
print(x+" "+y )
# Out:
# sumit joshi

# %% [markdown]
# Q5: Declare three variables, consisting of your first name, your last name and
# Nickname. Write a program that prints out your first name, then your nickname
# in parenthesis and then your last name.
# Example output: George (woody) Washington.

# %%
x="sumit"
y="(sumi)"
z="joshi"
print(x+" "+y+" "+z)
# Out:
# sumit (sumi) joshi

# %% [markdown]
# Q6:Declare and assign values to suitable variables and print in the following way:
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
# Bidholi Campus
# Pincode: 248007
# Programme: AI & ML
# Semester: 2

# %%
print("Name: Sumit Joshi")
print("sap id:590021128")
print("Branch: Computer Science and Engineering")
print("College: Sardar Patel Institute of Technology")
print("I am a third year student at SPIT and I am interested in learning new technologies and exploring the field of computer science. I have a passion for coding and enjoy working on projects that challenge me to think creatively and solve problems. In my free time, I like to read about the latest advancements in technology and experiment with new programming languages. I am excited to continue my journey in the world of computer science and see where it takes me in the future.")
# Out:
# Name: Sumit Joshi
# sap id:590021128
# Branch: Computer Science and Engineering
# College: Sardar Patel Institute of Technology
# I am a third year student at SPIT and I am interested in learning new technologies and exploring the field of computer science. I have a passion for coding and enjoy working on projects that challenge me to think creatively and solve problems. In my free time, I like to read about the latest advancements in technology and experiment with new programming languages. I am excited to continue my journey in the world of computer science and see where it takes me in the future.
