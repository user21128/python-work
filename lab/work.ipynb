# %%
class Counter:
    def __init__(self):
        self.value = 0

    def inc(self):
        self.value += 1

    def dec(self):
        self.value -= 1

    def show(self):
        return self.value
c = Counter()
c.inc()

# %%
class Student:
    def set_details(self, name, roll):
        self.name = name
        self.roll = roll

    def display(self):
        print(self.name, self.roll)

s1 = Student()
s1.set_details("Aman", 101)
s2 = Student()
s2.set_details("Rohit", 102)
s3 = Student()
s3.set_details("Sneha", 103)
s3.display()
s2.display()
s1.display()
# Out:
# Sneha 103
# Rohit 102
# Aman 101

# %%
class hello:
    def __init__(self, name):
        self.name = name

    def say_hello(self):
        print(f"Hello, {self.name}!")
h1 = hello("Aman")
h1.say_hello()
h2 = hello("Rohit")
h2.say_hello()
h3 = hello("Sneha")
h3.say_hello()
h4 = hello("Ankit")
h4.say_hello()
h5 = hello("Anjali")
h5.say_hello()
h6 = hello("Anshul")
h6.say_hello()
h7 = hello("Anshul")
h7.say_hello()
# Out:
# Hello, Aman!
# Hello, Rohit!
# Hello, Sneha!
# Hello, Ankit!
# Hello, Anjali!
# Hello, Anshul!
# Hello, Anshul!

# %%
class Student:
    class student:
        def __init__(self, name):
            self.name = name
    college = "UPES"   # class variable
    college2 = "des Dehradun"  # class variable
    name = "Aman"  # class variable

    def __init__(self, name):
        self.name = name  # instance variable

s1 = Student("Aman")
s2 = Student("Riya")
s3 = Student("Sneha")
s4= Student("Ankit")
s5=Student("Anjali")
s6=Student("Anshul")
s7=Student("hekko")

print(s1.college, s2.college, s3.college)
print(s1.college2, s2.college2, s3.college2)
print(s1.college, s2.college, s3.college)
# Out:
# UPES UPES UPES
# des Dehradun des Dehradun des Dehradun
# UPES UPES UPES

# %%
class Student:
    college = "UPES"

    @classmethod
    def set_college(cls, new_name):
        cls.college = new_name
s1 = Student()
s2 = Student()
s3 = Student()
s4 = Student()
s5 = Student()
s6 = Student()
s7 = Student()
print(s1.college, s2.college, s3.college)
Student.set_college("des Dehradun")
print(s3.college, s4.college, s5.college)
# Out:
# UPES UPES UPES
# des Dehradun des Dehradun des Dehradun

# %%
class MathUtil:
    @staticmethod
    def is_even(n):
        return n % 2 == 0

# %%
class Account:
    def __init__(self, balance):
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, value):
        if value < 0:
            raise ValueError("Balance cannot be negative")
        self.__balance = value
        a = Account(100)
        print(a.balance)
        a.balance = 200
        self.__balance = value

# %% [markdown]
# ## practice

# %%
the_world_is_flat = False
if the_world_is_flat:
    print("stop living in the cave")

the_world_is_flat = True
if the_world_is_flat:
    print("are you living in the cave?")
# Out:
# are you living in the cave?

# %%
rain = False
if rain:
    print("take an umbrella")
umbrella= 1
if umbrella:
    print("take an umbrella")
jog = None
if jog:
    print("go for a jog")
# Out:
# take an umbrella

# %%
true = False
false = True
print(true, false)
if true == False:
    print("the world is flat")
else:
    print("the world is not flat")
# Out:
# False True
# the world is flat

# %%
def spam() :
    eggs = 10
    return

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
