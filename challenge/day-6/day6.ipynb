# %%
# previously we learned to make a simplle program to get name age and phone and performed various operations

#### now ill try making window to add a basic gui for the program

# %% [markdown]
# # this is day 6 and ill try to add a simple window using python

# %%
# making a simple window without improting any library
def make_window():
    print("-" * 80)
    print("--------------------Welcome to my program-----------------------")
    print("-" * 80)
make_window()

# how about i try making something cool? like a gui with loops? idk

def make_window():
    for i in range(10):
        print("|" * (i + 1))
make_window()
def left_window():
    for i in range(10):
        print("|" * (i - -+9))
left_window()
# Out:
# --------------------------------------------------------------------------------
# --------------------Welcome to my program-----------------------
# --------------------------------------------------------------------------------
# |
# ||
# |||
# ||||
# |||||
# ||||||
# |||||||
# ||||||||
# |||||||||
# ||||||||||
# |||||||||
# ||||||||||
# |||||||||||
# ||||||||||||
# |||||||||||||
# ||||||||||||||
# |||||||||||||||
# ||||||||||||||||
# |||||||||||||||||
# ||||||||||||||||||

# %%
# lets just try tkinter
import tkinter as tk
window = tk.Tk()
window.title("my first window")
window.geometry("600x400")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import tkinter as tk
window = tk.Tk()
window.title("my first window")
window.geometry("600x400")
window.config(bg="blue")
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 window.geometry("600x400")
#       5 window.config(bg="blue")
# ----> 6 window.mainloop(1)
#
# File c:\Users\fourk\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py:1599, in Misc.mainloop(self, n)
#    1597 def mainloop(self, n=0):
#    1598     """Call the mainloop of Tk."""
# -> 1599     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
#lets just try adding some contents in our newly made window 
import tkinter as tk
window = tk.Tk()
window.title("my first window")
window.geometry("600x400")
window.config(bg="black")
ttk.button()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
