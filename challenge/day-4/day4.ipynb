# %% [markdown]
# # this is day 4 of the challenge for python programming
# ---------
# today im thinking of making a simple calculator maybe a stopwatch or a timer tooo....

# %%
def add (x, y):
    return x + y
def subtract (x, y):
    return x - y
def multiply (x, y):
    return x * y
def divide (x, y):
    return x / y
operation = input("select an operation (1/2/3/4) : ")
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
if operation == '1':
    print(num1, "+", num2, "=", add(num1, num2))
elif operation == '2':
    print(num1, "-", num2, "=", subtract(num1, num2))
elif operation == '3':
    print(num1, "*", num2, "=", multiply(num1, num2))
elif operation == '4':
    print(num1, "/", num2, "=", divide(num1, num2))
else:
    print("Invalid input")
while True:
    pass
else:   print("Invalid input")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 def divide (x, y):
#       8     return x / y
# ----> 9 operation = input("select an operation (1/2/3/4) : ")
#      10 num1 = float(input("Enter first number: "))
#      11 num2 = float(input("Enter second number: "))
#
# File c:\Users\fourk\Desktop\repo\python-work\.venv\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# ...

# %% [markdown]
# ------
# let's make something much cool

# %%
passwords = {}
def add_password(service, password):
    passwords[service] = password
    print(f"Password for {service} added.")
def get_password(service):
    if service in passwords:
        print(f"Password for {service}: {passwords[service]}")
    else:
        print(f"No password found for {service}.")
while True:
    action = input("Do you want to add a password or get a password? (add/get/exit): ")
    if action == "add":
        service = input("Enter the service name: ")
        password = input("Enter the password: ")
        add_password(service, password)
    elif action == "get":
        service = input("Enter the service name: ")
        get_password(service)
    elif action == "exit":
        print("Exiting the program.")
        break
    else:
        print("Invalid input. Please enter 'add', 'get', or 'exit'.")
print("Program terminated.", end="")
# Out:
# Password for add added.
# Password for add: sjkhfkaj
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# Invalid input. Please enter 'add', 'get', or 'exit'.
# ...

# %% [markdown]
# ## lets make a stopwatch
# -------

# %%
def stopwatch():
    import time
    start_time = time.time()
    input("Press Enter to stop the stopwatch...")
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Elapsed time: {elapsed_time:.2f} seconds")
stopwatch()
# Out:
# Elapsed time: 6.48 seconds

# %%
def timer(seconds):
    import time
    print(f"Timer set for {seconds} seconds.")
    time.sleep(seconds)
    print("Time's up!")
seconds = int(input("Enter the number of seconds for the timer: "))
timer(seconds)
# Out:
# Timer set for 5 seconds.
# Time's up!
