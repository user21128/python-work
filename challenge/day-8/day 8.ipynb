# %% [markdown]
# #### Q1. Take a string and print each character using loop.

# %%
s=input("Enter a string: ")
for i in s:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# #### Q2. Take two strings and join them using a dash (-).

# %%
s1=input("Enter a string: ")
s2=input("Enter another string: ")
print(s1+ "-" +s2)
# Out:
# hello-world

# %% [markdown]
# #### 3. Check whether the quadratic equation has real roots or imaginary roots. Display the roots.

# %%
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))
c = int(input("Enter a third number: "))
d = b**2 - 4*a*c
if d > 0:
    print("The equation has two real roots", d)
elif d == 0:
    print("The equation has one real root", d)
elif d < 0:
    print("The equation has imaginary roots", d)

# %% [markdown]
# #### 10 Check if two strings are anagrams.

# %%
s1 = input("Enter first string: " )
s2 = input("Enter second string: " )
if sorted(s1) == sorted(s2):
    print("Anagrams")
else:
    print("Not anagrams")

# %% [markdown]
# #### Q5. Remove spaces from string.

# %%
s=input("Enter a string: ")

print(s.replace(" ",""))
# Out:
# ayuraw

# %% [markdown]
# #### Q3) Print Fibonacci series up to given term.

# %%
n=int(input("enter a no: "))
a=0
b=1
for i in range(n):
    print(a,end=" ")
    c=a+b
    a=b
    b=c

# %% [markdown]
# #### Q7. Print Pascal-like pattern (simple version).

# %%
n=int(input("Enter number of rows: "))
for i in range(1, n+1):
    print(['*']*i)
# Out:
# ['*']
# ['*', '*']
# ['*', '*', '*']
# ['*', '*', '*', '*']
# ['*', '*', '*', '*', '*']

# %% [markdown]
# #### Q8. Find substring position using find().

# %%
s = input("Enter string: ")
sub = input("Enter substring: ")

print(s.find(sub))
# Out:
# 1

# %% [markdown]
# #### Q5) Check whether given number is palindrome or not.

# %%
n=input("enter a no: ")
if n==n[::-1]:
    print("its palindrome")
else:
    print("not palindrome")

# %% [markdown]
# #### Q10. Menu-driven Calculator

# %%
while True:
    print("Menu:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Exit")
    
    choice = input("Enter your choice: ")
    
    if choice == '5':
        print("Exiting...")
        break
    
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
    
    if choice == '1':
        print(f"Result: {num1 + num2}")
    elif choice == '2':
        print(f"Result: {num1 - num2}")
    elif choice == '3':
        print(f"Result: {num1 * num2}")
    elif choice == '4':
        if num2 != 0:
            print(f"Result: {num1 / num2}")
        else:
            print("Error: Division by zero")
    else:
        print("Invalid choice, please try again.")
# Out:
# Menu:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Result: 88.0
# Menu:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Exiting...

# %% [markdown]
# #### Q11. Find intersection of two sets.

# %%
A.intersection(B)
# Out:
# {3}

# %% [markdown]
# #### Q12. Predict output:</h4>

# %%
for i in range(3):
    for j in range(2):
        print(i, j)

# %% [markdown]
# #### Q13. Find longest word in sentence.

# %%
s = input("Enter a sentence: ")

words = s.split()
longest = max(words, key=len)

print("Longest word:", longest)
# Out:
# Longest word: dajblgdyua

# %% [markdown]
# #### 14. WAP to enter a string and a substring. You have to print the number of times that the substring occurs in the given string. String traversal will take place from left to right, not from right to left.

# %%
main_string=input("enter a string:")#banana
sub_string=input("enter a sub string:")#na
count=0
n=len(main_string)#6
m=len(sub_string)#2
for i in range(n-m+1):
    if(main_string[i:i+m]==sub_string):
        count+=1

print("",count)

# %% [markdown]
# #### 3.Print substring using slicing.

# %%
s = input("Enter a string: " )
print(s[1:4], "is a substring of the string.")

# %% [markdown]
# #### Q16. Print the following using two different methods:<h5>Welcome to Python !!!<br>Learning<br>Python</h5>

# %%
print("""Welcome to Python !!!
Learning
Python""")
# Out:
# Welcome to Python !!!
# Learning
# Python

# %% [markdown]
# #### Q17. Check substring exists or not.

# %%
s = input("Enter string: ")
sub = input("Enter substring: ")

if sub in s:
    print("Found")
else:
    print("Not Found")
# Out:
# Not Found

# %% [markdown]
# #### Q18. Print reverse pattern:</h4><h5>****<br>***<br>**<br>*</h5>

# %%
for i in range(4, 0, -1):
    print("*" * i)
# Out:
# ****
# ***
# **
# *
